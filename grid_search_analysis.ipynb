# %% [markdown]
# # Grid Search Analysis & Review Export
#
# Reads the per-category CSV produced by `ocr_grid_search.ipynb`, shows which
# parameters mattered, and exports the best results for human review.
#
# ---
#
# ## Usage
#
# Set `TARGET_ID` in the CONFIG cell to match the run you just completed, then
# run all cells top to bottom. The export cell writes to
# `review_export/{category}/{pdf_name}/`, after which:
#
# ```bash
# rclone copy ~/Documents/tibetan-ocr-app/grid_search_results/review_export/ \
#   "gdrive:Tibetan OCR Gridsearch Project Folder/review_export" --progress
# ```
#
# Use `copy`, not `sync` — `sync` deletes anything on Drive that isn't local.
#
# ---
#
# ## Trimming parameters
#
# After a Phase 1 full-grid run, use the by-parameter tables to decide what to
# drop:
#
# - A parameter whose values all score the same is a candidate for pinning
# - A parameter with a clear winner is a candidate for dropping the losers
# - **Judge on composite, not raw quality.** A page yielding five tokens can
#   score 100% and be worthless
#
# Then add a named grid to the PARAMETERS cell in `ocr_grid_search.ipynb` with a
# comment recording the reasoning.
#
# ---
#
# ## The export bug this cell was rewritten to fix
#
# **August 2026.** The previous export located a result file by globbing
# `{model}_{mode}_*`, filtering for `bbox{tolerance}`, and taking the first
# filesystem match. It ignored `k_factor`, `merge_lines`, `tps_threshold` and
# `class_threshold`.
#
# That worked when it was written in April, because the trimmed grid was small
# enough that the glob was nearly unique. It broke silently as the grid grew. On
# a full-grid page it was choosing blindly among many siblings.
#
# An audit found **33 of 56 verifiable exports carried a score describing a
# different run than the text in the file** — roughly 59%. Every export from
# April 21 onward was affected. A reviewer caught it from the outside, noticing
# that scores and output quality sometimes disagreed.
#
# A second flaw compounded it: "top 3 by composite" was chosen by score alone, so
# near-identical runs filled all three slots. Reviewers received the same text
# three times with three different numbers attached.
#
# ### What the rewrite does
#
# 1. **Exact selection.** Rebuilds `params.to_filename()` from the CSV row and
#    opens that specific file. No globbing.
# 2. **Dedupe on content.** Compares actual OCR text and skips duplicates, so
#    three versions means three genuinely different ones.
# 3. **Read-back verification.** Reopens the written file and asserts its embedded
#    `Quality Score` matches the CSV row. On mismatch it refuses to export that
#    row and reports it, rather than shipping a mislabeled file.
#
# The verification is the important part. It converts a silent, invisible failure
# into a loud one.
#
# ---
#
# ## Scoring
#
# - **quality_score (0–100)** — percentage of tokens PyBo tags as valid Tibetan
# - **composite** — `quality_score x total_tokens`
#
# Composite is the ranking metric. Raw quality alone rewards sparse pages.
#
# PyBo gives partial credit to garbage that happens to tokenize, so a high score
# is evidence rather than proof. Human review remains the ground truth.
#
# ---
#
# ## Output layout
#
# ```
# review_export/{category}/{pdf_name}/
#     page_1_original.jpg
#     page_1_Woodblock-Stacks_q89.7_c676.5.txt
#     page_1_Woodblock_q88.3_c667.8.txt
# ```
#
# Each `.txt` holds clean OCR text only, no header — it is meant to be read
# alongside the original image.

# %%
"""
=============================================================================
CONFIG — set TARGET_ID to match ocr_grid_search.ipynb
=============================================================================
"""
import pandas as pd
import shutil
from pathlib import Path

TARGET_ID = 31   # match this to ocr_grid_search.ipynb
TOP_N = 3        # number of top results to export per page

# =============================================================================

BASE_DIR   = Path.home() / 'Documents' / 'tibetan-ocr-app'
OUTPUT_DIR = BASE_DIR / 'grid_search_results'
TEMP_DIR   = OUTPUT_DIR / 'temp_images'

TARGETS = {
    1:  ('uchen_high_quality_examples/uchen high quality pdf.pdf',          'uchen_high'),
    2:  ('uchen_high_quality_examples/uchen_high_quality_.pdf',              'uchen_high'),
    3:  ('uchen_high_quality_examples/uchen_high_quality_pdf.pdf',           'uchen_high'),
    4:  ('uchen_medium_quality_examples/uchen_medium quality.pdf',            'uchen_medium'),
    5:  ('uchen_medium_quality_examples/uchen_medium quality(1).pdf',         'uchen_medium'),
    6:  ('uchen_poor_quality_examples/uchen_tsalyig_poor quality.pdf',        'uchen_poor'),
    7:  ('uchen_poor_quality_examples/uchen_poor quality.pdf',                'uchen_poor'),
    8:  ('uchen_poor_quality_examples/uchen_poor quality(1).pdf',             'uchen_poor'),
    9:  ('umeh_high_quality_examples/umeh_druma_high quality.pdf',            'umeh_druma_high'),
    10: ('umeh_high_quality_examples/umeh_drutsa_high quality.pdf',           'umeh_drutsa_high'),
    11: ('umeh_high_quality_examples/umeh_dhernangdri_high quality(1).pdf',   'umeh_dhernangdri_high'),
    12: ('umeh_high_quality_examples/umeh_dhernangdri_high quality.pdf',      'umeh_dhernangdri_high'),
    13: ('umeh_high_quality_examples/umeh_dhernangdri_high quality(2).pdf',   'umeh_dhernangdri_high'),
    14: ('umeh_high_quality_examples/umeh_tsugma khyug_high quality.pdf',     'umeh_tsugmakhyug_high'),
    15: ('umeh_medium_quality_examples/umeh_druchen_medium quality.pdf',       'umeh_medium'),
    16: ('umeh_medium_quality_examples/umeh_druchen_medium quality(1).pdf',    'umeh_medium'),
    17: ('umeh_medium_quality_examples/umeh_dhernangdri_medium quality.pdf',   'umeh_medium'),
    18: ('umeh_medium_quality_examples/umeh_tsugmakhyug_medium quality.pdf',   'umeh_medium'),
    19: ('umeh_medium_quality_examples/umeh_druchen_medium quality(2).pdf',    'umeh_medium'),
    20: ('umeh_poor_quality_examples/umeh_dhernangdri_poor quality(2).pdf',    'umeh_poor'),
    21: ('umeh_poor_quality_examples/umeh_drutsa_poor quality.pdf',            'umeh_poor'),
    22: ('umeh_poor_quality_examples/umeh_khyugyig_poor quality.pdf',          'umeh_poor'),
    23: ('umeh_poor_quality_examples/umeh_petsug_poor quality.pdf',            'umeh_poor'),
    24: ('Pechas with more text/pechas with more text 1.pdf',                  'pechas_more_text'),
    25: ('Pechas with more text/pechas with more text 2.pdf',                  'pechas_more_text'),
    26: ('Pechas with more text/pechas with more text 3.pdf',                  'pechas_more_text'),
    27: ('Pechas with little text/pechas with little text 1.pdf',              'pechas_little_text'),
    28: ('Pechas with little text/pechas with little text 2.pdf',              'pechas_little_text'),
    29: ('Pechas with little text/pechas with little text 3.pdf',              'pechas_little_text'),
    30: ('sangs rgyas sman bla dngos.pdf',                                     'standalone'),
    31: ('sangs_rgyas_sman_gyi.pdf',                                           'uchen_medium'),
}

_path, CATEGORY = TARGETS[TARGET_ID]
TARGET_STEM = Path(_path).stem
CSV_PATH = OUTPUT_DIR / f'summary_{TARGET_STEM}.csv'

print(f'Target #{TARGET_ID}: {TARGET_STEM}')
print(f'Category: {CATEGORY}')
print(f'CSV: {CSV_PATH.name}')
print(f'Exists: {CSV_PATH.exists()}')
# Out:
# Target #31: sangs_rgyas_sman_gyi
# Category: uchen_medium
# CSV: summary_sangs_rgyas_sman_gyi.csv
# Exists: True

# %%
"""
Load data and show summary.
"""
if not CSV_PATH.exists():
    raise FileNotFoundError(f'CSV not found: {CSV_PATH}. Run grid search first.')

df = pd.read_csv(CSV_PATH)
successful = df[df['success'] == True].copy()
successful['composite'] = successful['quality_score'] * successful['total_tokens']

print(f'Total results: {len(df)}')
print(f'Successful: {len(successful)}')
print(f'Failed: {len(df) - len(successful)}')
print(f'Pages: {sorted(df["image_name"].unique())}')
print(f'\nRows per page:')
print(df.groupby('image_name').size().to_string())
# Out:
# Total results: 20736
# Successful: 20460
# Failed: 276
# Pages: ['sangs_rgyas_sman_gyi - page 1', 'sangs_rgyas_sman_gyi - page 10', 'sangs_rgyas_sman_gyi - page 11', 'sangs_rgyas_sman_gyi - page 12', 'sangs_rgyas_sman_gyi - page 2', 'sangs_rgyas_sman_gyi - page 3', 'sangs_rgyas_sman_gyi - page 4', 'sangs_rgyas_sman_gyi - page 5', 'sangs_rgyas_sman_gyi - page 6', 'sangs_rgyas_sman_gyi - page 7', 'sangs_rgyas_sman_gyi - page 8', 'sangs_rgyas_sman_gyi - page 9']
#
# Rows per page:
# image_name
# sangs_rgyas_sman_gyi - page 1     1728
# sangs_rgyas_sman_gyi - page 10    1728
# sangs_rgyas_sman_gyi - page 11    1728
# sangs_rgyas_sman_gyi - page 12    1728
# sangs_rgyas_sman_gyi - page 2     1728
# sangs_rgyas_sman_gyi - page 3     1728
# sangs_rgyas_sman_gyi - page 4     1728
# sangs_rgyas_sman_gyi - page 5     1728
# sangs_rgyas_sman_gyi - page 6     1728
# sangs_rgyas_sman_gyi - page 7     1728
# sangs_rgyas_sman_gyi - page 8     1728
# sangs_rgyas_sman_gyi - page 9     1728

# %%
"""
Average quality and composite scores by parameter.
Use this to decide what to trim for the next run.
"""
print('=' * 70)
print('QUALITY SCORE BY PARAMETER')
print('=' * 70)

for param in ['ocr_model_name', 'line_mode', 'k_factor', 'bbox_tolerance',
              'merge_lines', 'tps_threshold', 'class_threshold']:
    print(f'\n--- {param} (quality) ---')
    print(successful.groupby(param)['quality_score'].mean().sort_values(ascending=False).to_string())

print('\n' + '=' * 70)
print('COMPOSITE SCORE BY PARAMETER (quality × tokens — more reliable)')
print('=' * 70)

for param in ['ocr_model_name', 'line_mode', 'k_factor', 'bbox_tolerance',
              'merge_lines', 'tps_threshold', 'class_threshold']:
    print(f'\n--- {param} (composite) ---')
    print(successful.groupby(param)['composite'].mean().sort_values(ascending=False).to_string())
# Out:
# ...
# QUALITY SCORE BY PARAMETER
# ...
#
# --- ocr_model_name (quality) ---
# ocr_model_name
# Woodblock-Stacks    66.122329
# Woodblock           57.992832
# Modern              53.543474
#
# --- line_mode (quality) ---
# line_mode
# layout    62.427419
# line      55.931234
#
# --- k_factor (quality) ---
# k_factor
# 2.5    59.269771
# 3.0    59.255053
# 2.0    59.144741
#
# --- bbox_tolerance (quality) ---
# bbox_tolerance
# 4.0    64.790760
# 5.0    63.308220
# 3.5    60.866316
# 2.5    47.866690
#
# --- merge_lines (quality) ---
# merge_lines
# False    59.426909
# True     59.020567
#
# --- tps_threshold (quality) ---
# tps_threshold
# 0.25    59.253082
# 0.50    59.253082
# 0.90    59.253082
# 0.10    59.129406
#
# --- class_threshold (quality) ---
# class_threshold
# 0.7    59.223142
# 0.8    59.223142
# 0.9    59.223142
#
# ...
# COMPOSITE SCORE BY PARAMETER (quality × tokens — more reliable)
# ...
#
# --- ocr_model_name (composite) ---
# ocr_model_name
# Woodblock-Stacks    4118.935842
# ...

# %%
"""
Top and bottom parameter combinations by composite score.
"""
print('=' * 70)
print('TOP 20 BY COMPOSITE SCORE')
print('=' * 70)
top20 = successful.nlargest(20, 'composite')[
    ['image_name', 'ocr_model_name', 'line_mode', 'k_factor',
     'bbox_tolerance', 'merge_lines', 'quality_score', 'total_tokens', 'composite']
]
print(top20.to_string(index=False))

print('\n' + '=' * 70)
print('QUALITY DISTRIBUTION')
print('=' * 70)
print(f'  >90 (Excellent): {len(successful[successful["quality_score"] > 90])}')
print(f'  70-90 (Good):    {len(successful[(successful["quality_score"] >= 70) & (successful["quality_score"] <= 90)])}')
print(f'  50-70 (Fair):    {len(successful[(successful["quality_score"] >= 50) & (successful["quality_score"] < 70)])}')
print(f'  <50 (Poor):      {len(successful[successful["quality_score"] < 50])}')
# Out:
# ...
# TOP 20 BY COMPOSITE SCORE
# ...
#                     image_name   ocr_model_name line_mode  k_factor  bbox_tolerance  merge_lines  quality_score  total_tokens  composite
# sangs_rgyas_sman_gyi - page 11 Woodblock-Stacks    layout       2.5             2.5        False          67.77           121    8200.17
# sangs_rgyas_sman_gyi - page 11 Woodblock-Stacks    layout       2.5             2.5        False          67.77           121    8200.17
# sangs_rgyas_sman_gyi - page 11 Woodblock-Stacks    layout       2.5             2.5        False          67.77           121    8200.17
# sangs_rgyas_sman_gyi - page 11 Woodblock-Stacks    layout       2.5             2.5        False          67.77           121    8200.17
# sangs_rgyas_sman_gyi - page 11 Woodblock-Stacks    layout       3.0             2.5        False          67.77           121    8200.17
# ...

# %%
"""
Inspect a specific OCR result file.
Change MODEL, MODE, PAGE to look at different results.
"""
MODEL = 'Ume_Druma'
MODE  = 'layout'
PAGE  = 1   # page number

page_name = f'{TARGET_STEM} - page {PAGE}'
result_dir = OUTPUT_DIR / TARGET_STEM / page_name

matches = list(result_dir.glob(f'{MODEL}_{MODE}_*')) if result_dir.exists() else []
print(f'Found {len(matches)} results for {MODEL}/{MODE} on page {PAGE}')
if matches:
    print(f'\nShowing: {matches[0].name}')
    print('-' * 40)
    with open(matches[0], 'r', encoding='utf-8') as f:
        print(f.read())
# Out:
# Found 0 results for Ume_Druma/layout on page 1

# %%
"""
=============================================================================
EXPORT TOP RESULTS FOR REVIEW — v2 (verified)
=============================================================================
Selects the best TOP_N genuinely-distinct results per page and writes them,
with the original page image, to review_export/{category}/{pdf_name}/.

v2 fixes two bugs present from April to August 2026:

  1. WRONG FILE SELECTED. v1 globbed '{model}_{mode}_*', filtered for
     'bbox{tolerance}', and took the first filesystem match — ignoring
     k_factor, merge_lines, tps_threshold and class_threshold. On a full-grid
     page that is a blind choice among many siblings. An audit found ~59% of
     exports carried a score describing different text.

     v2 rebuilds the exact to_filename() string from the CSV row.

  2. DUPLICATE VERSIONS. v1 took top 3 by composite score alone, so
     near-identical runs filled every slot. Reviewers got the same text three
     times with three different numbers on it.

     v2 dedupes on actual OCR text before selecting.

And it adds a check that did not exist at all:

  3. READ-BACK VERIFICATION. Each raw file carries its own 'Quality Score'
     line. v2 reads it and compares against the CSV row. On mismatch it
     refuses to export that row and reports it.

Run after ALL pages in a category are complete.
=============================================================================
"""

import re
import hashlib

# Tolerance for score comparison. Filenames carry one decimal, so a CSV value
# of 41.96 legitimately becomes q42.0 — anything under 0.05 is rounding.
SCORE_TOLERANCE = 0.05


def build_result_filename(row) -> str:
    """
    Reconstruct params.to_filename() from a CSV row.

    MUST match GridSearchParams.to_filename() in ocr_grid_search.ipynb exactly.
    If that format ever changes, this breaks and the verification below will
    catch it as a missing file rather than a silent mislabel.
    """
    merge = row['merge_lines']
    if isinstance(merge, str):
        merge = merge.strip().lower() == 'true'
    merge_str = 'T' if merge else 'F'

    return (
        f"{row['ocr_model_name']}_{row['line_mode']}_"
        f"k{row['k_factor']}_bbox{row['bbox_tolerance']}_"
        f"merge-{merge_str}_tps{row['tps_threshold']}_"
        f"conf{row['class_threshold']}"
    )


def read_raw_result(path: Path):
    """
    Parse a raw result file into (embedded_quality_score, clean_ocr_text).

    Returns (None, None) if unreadable. The embedded score is what makes
    verification possible — each file states its own provenance.

    NOTE ON FILE FORMAT (added Aug 2026):
        Result files written before ~April 2026 have NO NEWLINES. The old
        save_result() joined its output lines without a separator, so the
        entire file is one continuous line.

        A line-by-line scan breaks on those files: it finds 'Quality Score:'
        inside the single giant line, then splits on the FIRST colon in that
        line — which belongs to 'File:' — and tries to parse the filename as
        a float. Result: score comes back None, and the verification below
        refuses every row.

        That is exactly what happened to umeh_druma_high and umeh_drutsa_high:
        1,704 and ~1,800 rows refused, zero files exported. The scores were
        present and correct the whole time; the parser just could not see them.

        Regexing the whole content instead of walking lines handles both the
        old and current formats, and is immune to future changes in how the
        file is assembled.
    """
    try:
        content = path.read_text(encoding='utf-8')
    except Exception:
        return None, None

    score = None
    m = re.search(r'Quality Score:\s*([0-9]+(?:\.[0-9]+)?)', content)
    if m:
        score = float(m.group(1))

    marker = 'OCR TEXT'
    if marker in content:
        idx = content.index(marker) + len(marker)
        while idx < len(content) and content[idx] in '\n=':
            idx += 1
        text = content[idx:].strip()
    else:
        text = content.strip()

    return score, text


# ── Export ───────────────────────────────────────────────────────────────────
total_exported = 0
stats = {'missing': [], 'mismatch': [], 'duplicate': 0, 'empty': 0}

for file_name in sorted(df['file_name'].unique()):
    file_df = successful[successful['file_name'] == file_name]
    pdf_dir = OUTPUT_DIR / 'review_export' / CATEGORY / file_name
    pdf_dir.mkdir(parents=True, exist_ok=True)

    for page_name in sorted(file_df['image_name'].unique()):
        page_df = file_df[file_df['image_name'] == page_name]

        parts = page_name.split(' - ')
        page_label = (parts[-1].replace(' ', '_') if len(parts) > 1
                      else page_name.replace(' ', '_'))

        # Copy the original page image so the reviewer can compare directly.
        image_dir = TEMP_DIR / file_name
        if image_dir.exists():
            for img_path in sorted(image_dir.glob('*.jpg')):
                if img_path.stem == page_name:
                    shutil.copy2(img_path, pdf_dir / f'{page_label}_original.jpg')
                    break

        # Walk candidates best-first, keeping only verified, distinct results
        # until TOP_N are collected. Ranking by score alone is what produced
        # triplicate identical exports in v1.
        candidates = page_df.sort_values('composite', ascending=False)
        seen_hashes = set()
        selected = []

        for _, row in candidates.iterrows():
            if len(selected) >= TOP_N:
                break

            fname = build_result_filename(row) + '.txt'
            raw_path = OUTPUT_DIR / row['file_name'] / row['image_name'] / fname

            if not raw_path.exists():
                stats['missing'].append(f'{page_label}: {fname}')
                continue

            embedded_score, ocr_text = read_raw_result(raw_path)

            if not ocr_text:
                stats['empty'] += 1
                continue

            # VERIFICATION: the file must agree with the row that selected it.
            if embedded_score is None or \
               abs(embedded_score - row['quality_score']) > SCORE_TOLERANCE:
                stats['mismatch'].append(
                    f'{page_label}: {fname} — CSV says '
                    f'q{row["quality_score"]:.2f}, file says {embedded_score}')
                continue

            # Dedupe on real content, not on score.
            text_hash = hashlib.sha256(ocr_text.encode('utf-8')).hexdigest()[:16]
            if text_hash in seen_hashes:
                stats['duplicate'] += 1
                continue
            seen_hashes.add(text_hash)

            selected.append((row, ocr_text))

        for row, ocr_text in selected:
            out_name = (f'{page_label}_{row["ocr_model_name"]}'
                        f'_q{row["quality_score"]:.1f}'
                        f'_c{row["composite"]:.1f}.txt')
            (pdf_dir / out_name).write_text(ocr_text, encoding='utf-8')
            total_exported += 1

        if len(selected) < TOP_N:
            print(f'  Note: {page_label} yielded only {len(selected)} distinct '
                  f'verified result(s) (wanted {TOP_N})')

# ── Report ───────────────────────────────────────────────────────────────────
export_dir = OUTPUT_DIR / 'review_export' / CATEGORY
print('\n' + '=' * 70)
print(f'EXPORT COMPLETE — {CATEGORY}')
print('=' * 70)
print(f'Location: {export_dir}')
print(f'OCR files written: {total_exported}')
print(f'Duplicates skipped: {stats["duplicate"]}')
print(f'Empty results skipped: {stats["empty"]}')

for subdir in sorted(export_dir.iterdir()):
    if subdir.is_dir():
        files = list(subdir.iterdir())
        jpgs = len([f for f in files if f.suffix == '.jpg'])
        txts = len([f for f in files if f.suffix == '.txt'])
        print(f'  {subdir.name}/ ({jpgs} JPGs, {txts} OCR files)')

if stats['mismatch']:
    print('\n' + '=' * 70)
    print(f'REFUSED — SCORE MISMATCH ({len(stats["mismatch"])})')
    print('=' * 70)
    print('These rows were NOT exported: the file contents disagreed with the')
    print('CSV. This is the v1 bug being caught. Investigate before shipping.')
    for m in stats['mismatch'][:20]:
        print(f'  {m}')

if stats['missing']:
    print('\n' + '=' * 70)
    print(f'MISSING RAW FILES ({len(stats["missing"])})')
    print('=' * 70)
    print('Expected result files that are not on disk. Either the run predates')
    print('the current filename format, or the files were deleted.')
    for m in stats['missing'][:20]:
        print(f'  {m}')

if not stats['mismatch'] and not stats['missing']:
    print('\n VERIFIED — every exported file matches its CSV row.')

print('\nSync to Google Drive:')
print('rclone copy ~/Documents/tibetan-ocr-app/grid_search_results/review_export/ '
      '"gdrive:Tibetan OCR Gridsearch Project Folder/review_export" --progress')
