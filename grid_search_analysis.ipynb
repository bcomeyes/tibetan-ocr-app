# %% [markdown]
# # Grid Search Results Analysis
#
# Analyze OCR grid search results. Run all cells top to bottom.

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path.home() / "Documents" / "tibetan-ocr-app"
OUTPUT_DIR = BASE_DIR / "grid_search_results"
CSV_PATH = OUTPUT_DIR / "summary.csv"

df = pd.read_csv(CSV_PATH)
successful = df[df['success'] == True]
failed = df[df['success'] == False]

print(f"Total results: {len(df)}")
print(f"Successful: {len(successful)}")
print(f"Failed: {len(failed)}")
print(f"Images tested: {df['image_name'].nunique()}")
# Out:
# Total results: 1920
# Successful: 1704
# Failed: 216
# Images tested: 3

# %%
print("=" * 70)
print("AVERAGE QUALITY SCORE BY PARAMETER")
print("=" * 70)

for param in ['ocr_model_name', 'line_mode', 'k_factor', 'bbox_tolerance',
              'merge_lines', 'tps_threshold', 'class_threshold']:
    print(f"\n--- {param} ---")
    print(successful.groupby(param)['quality_score'].mean().sort_values(ascending=False))
# Out:
# ======================================================================
# AVERAGE QUALITY SCORE BY PARAMETER
# ======================================================================
#
# --- ocr_model_name ---
# ocr_model_name
# Ume_Druma     52.757641
# Modern        48.794754
# Ume_Petsuk    48.125493
# Name: quality_score, dtype: float64
#
# --- line_mode ---
# line_mode
# layout    50.083875
# line      49.645860
# Name: quality_score, dtype: float64
#
# --- k_factor ---
# k_factor
# 2.0    51.436300
# 2.5    51.281467
# 3.0    46.401548
# Name: quality_score, dtype: float64
#
# --- bbox_tolerance ---
# bbox_tolerance
# 2.5    54.862629
# 3.5    49.892911
# 4.0    47.694178
# 5.0    47.120798
# Name: quality_score, dtype: float64
#
# --- merge_lines ---
# merge_lines
# False    50.301197
# True     49.484061
# Name: quality_score, dtype: float64
#
# --- tps_threshold ---
# tps_threshold
# 0.10    49.944877
# 0.25    49.876181
# 0.50    49.876181
# 0.90    49.876181
# Name: quality_score, dtype: float64
#
# --- class_threshold ---
# class_threshold
# 0.8    49.904881
# 0.9    49.904881
# 0.7    49.874885
# Name: quality_score, dtype: float64

# %%
print("=" * 70)
print("TOP 20 PARAMETER COMBINATIONS")
print("=" * 70)

top20 = successful.nlargest(20, 'quality_score')[
    ['image_name', 'ocr_model_name', 'line_mode', 'k_factor',
     'bbox_tolerance', 'merge_lines', 'tps_threshold',
     'class_threshold', 'quality_score', 'num_lines_detected']
]
print(top20.to_string(index=False))
# Out:
# ======================================================================
# TOP 20 PARAMETER COMBINATIONS
# ======================================================================
#                       image_name ocr_model_name line_mode  k_factor  bbox_tolerance  merge_lines  tps_threshold  class_threshold  quality_score  num_lines_detected
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.10              0.7          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.25              0.7          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.50              0.7          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.90              0.7          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.10              0.8          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.25              0.8          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.50              0.8          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.90              0.8          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.10              0.9          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.25              0.9          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.50              0.9          86.67                   5
# umeh_druma_high quality - page 1         Modern    layout       2.0             5.0        False           0.90              0.9          86.67                   5
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.25              0.7          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.50              0.7          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.90              0.7          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.25              0.8          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.50              0.8          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.90              0.8          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.25              0.9          83.33                   3
# umeh_druma_high quality - page 1      Ume_Druma      line       2.5             2.5         True           0.50              0.9          83.33                   3

# %%
print("=" * 70)
print("BOTTOM 20 PARAMETER COMBINATIONS (successful only)")
print("=" * 70)

bottom20 = successful.nsmallest(20, 'quality_score')[
    ['image_name', 'ocr_model_name', 'line_mode', 'k_factor',
     'bbox_tolerance', 'merge_lines', 'tps_threshold',
     'class_threshold', 'quality_score', 'num_lines_detected']
]
print(bottom20.to_string(index=False))
# Out:
# ======================================================================
# BOTTOM 20 PARAMETER COMBINATIONS (successful only)
# ======================================================================
#                       image_name ocr_model_name line_mode  k_factor  bbox_tolerance  merge_lines  tps_threshold  class_threshold  quality_score  num_lines_detected
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.25              0.7          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.50              0.7          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.90              0.7          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.25              0.8          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.50              0.8          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.90              0.8          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.25              0.9          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.50              0.9          20.00                   3
# umeh_druma_high quality - page 1         Modern      line       3.0             2.5         True           0.90              0.9          20.00                   3
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.25              0.7          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.50              0.7          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.90              0.7          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.25              0.8          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.50              0.8          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.90              0.8          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.25              0.9          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.50              0.9          21.43                   4
# umeh_druma_high quality - page 1     Ume_Petsuk      line       2.0             2.5        False           0.90              0.9          21.43                   4
# umeh_druma_high quality - page 2         Modern      line       2.0             3.5         True           0.10              0.7          24.39                   4
# umeh_druma_high quality - page 2         Modern      line       2.0             3.5        False           0.10              0.7          24.39                   4

# %%
print("=" * 70)
print("QUALITY DISTRIBUTION")
print("=" * 70)
print(f"  >90 (Excellent): {len(successful[successful['quality_score'] > 90])}")
print(f"  70-90 (Good):    {len(successful[(successful['quality_score'] >= 70) & (successful['quality_score'] <= 90)])}")
print(f"  50-70 (Fair):    {len(successful[(successful['quality_score'] >= 50) & (successful['quality_score'] < 70)])}")
print(f"  <50 (Poor):      {len(successful[successful['quality_score'] < 50])}")
# Out:
# ======================================================================
# QUALITY DISTRIBUTION
# ======================================================================
#   >90 (Excellent): 0
#   70-90 (Good):    129
#   50-70 (Fair):    808
#   <50 (Poor):      767

# %%
print("=" * 70)
print("BEST vs WORST OCR OUTPUT")
print("=" * 70)

best = successful.nlargest(1, 'quality_score').iloc[0]
worst = successful.nsmallest(1, 'quality_score').iloc[0]

best_dir = OUTPUT_DIR / best['file_name'] / best['image_name']
worst_dir = OUTPUT_DIR / worst['file_name'] / worst['image_name']

best_files = list(best_dir.glob(f"{best['ocr_model_name']}_{best['line_mode']}_*"))
worst_files = list(worst_dir.glob(f"{worst['ocr_model_name']}_{worst['line_mode']}_*"))

if best_files:
    print(f"\nBEST (score={best['quality_score']}, model={best['ocr_model_name']}, mode={best['line_mode']}):")
    print("-" * 40)
    with open(best_files[0], 'r', encoding='utf-8') as f:
        print(f.read())

if worst_files:
    print(f"\nWORST (score={worst['quality_score']}, model={worst['ocr_model_name']}, mode={worst['line_mode']}):")
    print("-" * 40)
    with open(worst_files[0], 'r', encoding='utf-8') as f:
        print(f.read())
# Out:
# ======================================================================
# BEST vs WORST OCR OUTPUT
# ======================================================================
#
# BEST (score=86.67, model=Modern, mode=layout):
# ----------------------------------------
# ======================================================================OCR RESULT======================================================================File: umeh_druma_high qualityImage: umeh_druma_high quality - page 1PARAMETERS:  OCR Model: Modern  Line Mode: layout  Class Threshold: 0.9  K-Factor: 2.5  BBox Tolerance: 3.5  Merge Lines: True  TPS Threshold: 0.9RESULTS:  Success: True  Lines Detected: 4  Processing Time: 3.90sQUALITY METRICS:  Quality Score: 57.14/100  Total Tokens: 14  Valid Words: 8  Invalid Words: 6======================================================================OCR TEXT======================================================================།༦ས༥།ཨིཔལྒེཡན།དོ།༥༦༠ཅྱི་ཉེག༧༥༠དོ།༦ཨི་ལ།གཡག༥་རེ།ག༠ཧན།གེ༡༧༠༠༡༥ཨོ།
#
# WORST (score=20.0, model=Modern, mode=line):
# ----------------------------------------
# ======================================================================OCR RESULT======================================================================File: umeh_druma_high qualityImage: umeh_druma_high quality - page 1PARAMETERS:  OCR Model: Modern  Line Mode: line  Class Threshold: 0.9  K-Factor: 3.0  BBox Tolerance: 4.0  Merge Lines: False  TPS Threshold: 0.5RESULTS:  Success: True  Lines Detected: 4  Processing Time: 3.64sQUALITY METRICS:  Quality Score: 55.56/100  Total Tokens: 9  Valid Words: 5  Invalid Words: 4======================================================================OCR TEXT======================================================================།གཏུཨི་པླྲིགཡ༥།ས༧ནེགལ༧༩དོ།ག༠པ་ཨི༥།ག།༽།

# %%
# Change the parameters below to look at a specific result
MODEL = "Woodblock-Stacks"
MODE = "line"
IMAGE = "uchen high quality pdf - page 1"
FILE = "uchen high quality pdf"

result_dir = OUTPUT_DIR / FILE / IMAGE
matches = list(result_dir.glob(f"{MODEL}_{MODE}_*"))
print(f"Found {len(matches)} results for {MODEL}/{MODE}")
if matches:
    print(f"\nShowing: {matches[0].name}")
    print("-" * 40)
    with open(matches[0], 'r', encoding='utf-8') as f:
        print(f.read())
# Out:
# Found 0 results for Woodblock-Stacks/line

# %%
"""
=============================================================================
EXPORT TOP RESULTS FOR REVIEW
=============================================================================
Picks top N results per page by composite score (quality * tokens),
copies the original JPG, and saves clean OCR text to review_export/.

Set CATEGORY to match what you just ran.
=============================================================================
"""
import shutil
import pandas as pd
from pathlib import Path

BASE_DIR = Path.home() / "Documents" / "tibetan-ocr-app"
OUTPUT_DIR = BASE_DIR / "grid_search_results"
TEMP_DIR = OUTPUT_DIR / "temp_images"
TOP_N = 3  # number of top results to export per page

# ============================================================================
# SET CATEGORY - uncomment ONE line
# ============================================================================
# CATEGORY = "uchen_high"
# CATEGORY = "uchen_medium"
# CATEGORY = "uchen_poor"
CATEGORY = "umeh_druma_high"
# CATEGORY = "umeh_drutsa_high"
# CATEGORY = "umeh_dhernangdri_high"
# CATEGORY = "umeh_tsugmakhyug_high"
# CATEGORY = "umeh_medium"
# CATEGORY = "umeh_poor"
# CATEGORY = "pechas_more_text"
# CATEGORY = "pechas_little_text"
# CATEGORY = "standalone"
# ============================================================================

df = pd.read_csv(OUTPUT_DIR / "summary.csv")
successful = df[df['success'] == True].copy()
successful['composite'] = successful['quality_score'] * successful['total_tokens']

file_names = successful['file_name'].unique()
print(f"Files in summary.csv: {list(file_names)}")

total_exported = 0

for file_name in sorted(file_names):
    file_df = successful[successful['file_name'] == file_name]
    pages = sorted(file_df['image_name'].unique())

    pdf_dir = OUTPUT_DIR / "review_export" / CATEGORY / file_name
    pdf_dir.mkdir(parents=True, exist_ok=True)

    for page_name in pages:
        page_df = file_df[file_df['image_name'] == page_name]
        top = page_df.nlargest(TOP_N, 'composite')

        parts = page_name.split(" - ")
        page_label = parts[-1].replace(" ", "_") if len(parts) > 1 else page_name.replace(" ", "_")

        # Copy original JPG
        image_dir = TEMP_DIR / file_name
        if image_dir.exists():
            for img_path in sorted(image_dir.glob("*.jpg")):
                if img_path.stem == page_name:
                    dest = pdf_dir / f"{page_label}_original.jpg"
                    shutil.copy2(img_path, dest)
                    break

        # Export top OCR text files
        for _, row in top.iterrows():
            result_dir = OUTPUT_DIR / row['file_name'] / row['image_name']
            model = row['ocr_model_name']
            mode = row['line_mode']
            matches = list(result_dir.glob(f"{model}_{mode}_*"))
            if not matches:
                continue

            target_bbox = row['bbox_tolerance']
            best_match = None
            for m in matches:
                if f"bbox{target_bbox}" in m.name:
                    best_match = m
                    break
            if not best_match:
                best_match = matches[0]

            with open(best_match, 'r', encoding='utf-8') as f:
                content = f.read()

            marker = "OCR TEXT"
            if marker in content:
                idx = content.index(marker) + len(marker)
                while idx < len(content) and content[idx] in '\n=':
                    idx += 1
                ocr_text = content[idx:].strip()
            else:
                ocr_text = content

            q = row['quality_score']
            c = row['composite']
            out_name = f"{page_label}_{model}_q{q:.1f}_c{c:.1f}.txt"
            with open(pdf_dir / out_name, 'w', encoding='utf-8') as f:
                f.write(ocr_text)
            total_exported += 1

print(f"\nExported to: {OUTPUT_DIR / 'review_export' / CATEGORY}")
print(f"Total files: {total_exported} OCR outputs + source images")
for subdir in sorted((OUTPUT_DIR / "review_export" / CATEGORY).iterdir()):
    if subdir.is_dir():
        print(f"  {subdir.name}/ ({len(list(subdir.iterdir()))} files)")
# Out:
# Files in summary.csv: ['umeh_druma_high quality']
#
# Exported to: /home/matt/Documents/tibetan-ocr-app/grid_search_results/review_export/umeh_druma_high
# Total files: 9 OCR outputs + source images
#   umeh_druma_high quality/ (9 files)
